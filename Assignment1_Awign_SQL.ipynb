# %%
from google.colab import files 
from IPython.display import Image

# %% [markdown]
# ## Table --> Employee

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c6bd9fc0-33e7-40a6-9d93-9d30a708be60" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6bd9fc0-33e7-40a6-9d93-9d30a708be60">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1.JPG to 1 (1).JPG

# %%
Image('1.JPG')

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd930bc0-f997-4839-aa33-a55db1c29edc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd930bc0-f997-4839-aa33-a55db1c29edc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2.jpg to 2 (1).jpg

# %%
Image('2.jpg')

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-83b74c62-f3c9-4f29-aa00-0069e184448d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-83b74c62-f3c9-4f29-aa00-0069e184448d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 3.jpg to 3 (1).jpg

# %%
Image('3.jpg')

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3d642009-595e-4718-a439-9afbcab420e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3d642009-595e-4718-a439-9afbcab420e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 4.jpg to 4 (1).jpg

# %%
Image('4.jpg')

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fbf0f850-b4f4-4bac-8082-29b785654b94" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fbf0f850-b4f4-4bac-8082-29b785654b94">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 5.jpg to 5 (1).jpg

# %%
Image('5.jpg')

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-049a596e-e356-4ec7-918d-ad1eff890292" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-049a596e-e356-4ec7-918d-ad1eff890292">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 6.jpg to 6 (1).jpg

# %%
Image('6.jpg')

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5184677e-7e07-4154-8355-9363461ae569" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5184677e-7e07-4154-8355-9363461ae569">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 7.jpg to 7 (1).jpg

# %%
Image('7.jpg')

# %% [markdown]
# ## Questions

# %%
# Q1. Select the detail of the employee whose name starts with P.
# Sol:- Select * from Employee where EmpName=’P%’;

# %%
# Q2. How many permanent candidates take a salary more than 5000.
# Sol:- Select count(IsPermanent) from EmpSalary where IsPermanent=’Yes’ and Salary>5000;

# %%
# Q3. Select the detail of the employee whose emailId is in gmail.
# Sol:- Select * from Employee where EmailId=’%gmail%’;

# %%
# Q4. Select the details of the employee who works either for department E-104 or E-102.
# Sol:- Select * from EmpDept where DeptId=’E-102’ or DeptId=’E-104’;

# %%
# Q5.  What is the department name for DeptID E-102?
# Sol:- Select DeptId, DeptName from EmpDept where DeptId=’E-102’;

# %%
# Q6. What is the total salary that is paid to permanent employees?
# Sol:- select SUM(DISTINCT Salary) AS "Total Salary" from EmpSalary where IsPermanent=’Yes’;

# %%
# Q7. List name of all employees whose name ends with a.
# Sol:- Select EmpName from Employee where EmpName like ‘%a’;

# %%
# Q8. List the number of departments of employees.
# Sol:- Select count(Department) from Employee

# %%
# Q9. How many projects started in 2010.
# Sol:- Select count(ProjectId) from EmpProject where StartYear=2010;

# %%
# Q10. How many projects started and finished in the same year.
# Sol:- Select count(ProjectId) from EmpProject where StartYear=EndYear;

# %%
# Q11. select the name of the employee whose name's 3rd character is 'h'.
# Sol:- Select EmpName from Employee where EmpName like ‘__h’;
